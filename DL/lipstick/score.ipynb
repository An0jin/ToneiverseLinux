# %% [markdown]
# # 립스틱 탐지모델 평가

# %%
# 성능 평가 패키지 설치
# %pip install ultralytics koreanize-matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 7.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 7.9 MB/s eta 0:00:00
# ...
#   Using cached polars-1.38.1-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached ultralytics_thop-2.0.18-py3-none-any.whl.metadata (14 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 kB 8.5 MB/s eta 0:00:00
# ...
#   Using cached polars_runtime_32-1.38.1-cp310-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 6.5 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 6.3 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 9.2 MB/s eta 0:00:0000:0100:01
# ...

# %%
from ultralytics import YOLO
import koreanize_matplotlib

# 학습된 립스틱 탐지 모델(train2의 best.pt) 가중치 로드
model = YOLO(f"runs/detect/train2/weights/best.pt")

# 검증 데이터셋에 대해 성능 평가 수행 (IoU 임계값 0.1, 클래스 무관 NMS 적용)
model.val(save=True, data="dataset/data.yaml", iou=0.1, agnostic_nms=True)
# Out:
# Ultralytics 8.4.12 🚀 Python-3.12.3 torch-2.6.0+cu124 CPU (13th Gen Intel Core i5-1334U)
# YOLOv12n summary (fused): 159 layers, 2,556,923 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 124.8±46.6 MB/s, size: 48.7 KB)
# val: Scanning /home/an0jin/Documents/GitHub/ToneiverseLinux/Yolo(DL)/lipstick/dataset/valid/labels.cache... 91 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 91/91 21.2Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.6s/it 9.7s2.0ss
#                    all         91        110      0.953      0.964      0.969      0.632
# Speed: 1.7ms preprocess, 99.5ms inference, 0.0ms loss, 0.5ms postprocess per image
# Results saved to /home/an0jin/Documents/GitHub/ToneiverseLinux/Yolo(DL)/lipstick/runs/detect/val2
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0])
# box: ultralytics.utils.metrics.Metric object
# ...
