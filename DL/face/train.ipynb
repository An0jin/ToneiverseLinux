# %% [markdown]
# # 퍼스널컬러 탐지모델 훈련

# %%
# Ultralytics (YOLO) 및 한글 폰트 지원 라이브러리 설치/업데이트
# %pip install -U ultralytics koreanize_matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ultralytics in /home/an0jin/.local/lib/python3.13/site-packages (8.4.12)
# Collecting ultralytics
#   Downloading ultralytics-8.4.157-py3-none-any.whl.metadata (46 kB)
# Requirement already satisfied: koreanize_matplotlib in /home/an0jin/.local/lib/python3.13/site-packages (0.1.1)
# Collecting cloudpickle>=3.1.1 (from ultralytics)
#   Using cached cloudpickle-3.1.2-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: filelock>=3.16.1 in /home/an0jin/.local/lib/python3.13/site-packages (from ultralytics) (3.18.0)
# Requirement already satisfied: numpy>=1.23.0 in /home/an0jin/.local/lib/python3.13/site-packages (from ultralytics) (2.1.1)
# Requirement already satisfied: matplotlib>=3.3.0 in /home/an0jin/.local/lib/python3.13/site-packages (from ultralytics) (3.10.1)
# Requirement already satisfied: opencv-python!=4.13.0.90,>=4.7.0 in /home/an0jin/.local/lib/python3.13/site-packages (from ultralytics) (4.11.0.86)
# Requirement already satisfied: pillow>=7.1.2 in /home/an0jin/.local/lib/python3.13/site-packages (from ultralytics) (11.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /home/an0jin/.local/lib/python3.13/site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /home/an0jin/.local/lib/python3.13/site-packages (from ultralytics) (2.32.5)
# Requirement already satisfied: torch>=1.8.0 in /home/an0jin/.local/lib/python3.13/site-packages (from ultralytics) (2.6.0)
# Requirement already satisfied: torchvision>=0.9.0 in /home/an0jin/.local/lib/python3.13/site-packages (from ultralytics) (0.21.0)
# Requirement already satisfied: psutil>=5.8.0 in /home/an0jin/.local/lib/python3.13/site-packages (from ultralytics) (7.0.0)
# Requirement already satisfied: polars>=0.20.0 in /home/an0jin/.local/lib/python3.13/site-packages (from ultralytics) (1.38.1)
# Collecting nvidia-ml-py>=12.0.0 (from ultralytics)
#   Using cached nvidia_ml_py-13.610.43-py3-none-any.whl.metadata (9.7 kB)
# Collecting ultralytics-thop>=2.1.6 (from ultralytics)
#   Using cached ultralytics_thop-2.1.6-py3-none-any.whl.metadata (13 kB)
# Collecting ultralytics-platform>=0.1.45 (from ultralytics)
#   Downloading ultralytics_platform-0.1.50-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /home/an0jin/.local/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/an0jin/.local/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/an0jin/.local/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/an0jin/.local/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /home/an0jin/.local/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/an0jin/.local/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/an0jin/.local/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.38.1 in /home/an0jin/.local/lib/python3.13/site-packages (from polars>=0.20.0->ultralytics) (1.38.1)
# Requirement already satisfied: six>=1.5 in /home/an0jin/.local/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/an0jin/.local/lib/python3.13/site-packages (from requests>=2.23.0->ultralytics) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/an0jin/.local/lib/python3.13/site-packages (from requests>=2.23.0->ultralytics) (3.19)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/an0jin/.local/lib/python3.13/site-packages (from requests>=2.23.0->ultralytics) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/an0jin/.local/lib/python3.13/site-packages (from requests>=2.23.0->ultralytics) (2025.1.31)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/an0jin/.local/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (4.16.0)
# Requirement already satisfied: networkx in /home/an0jin/.local/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /home/an0jin/.local/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /home/an0jin/.local/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/an0jin/.local/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/an0jin/.local/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/an0jin/.local/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/an0jin/.local/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/an0jin/.local/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/an0jin/.local/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/an0jin/.local/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/an0jin/.local/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/an0jin/.local/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /home/an0jin/.local/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/an0jin/.local/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/an0jin/.local/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/an0jin/.local/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /home/an0jin/.local/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (3.2.0)
# Requirement already satisfied: setuptools in /home/an0jin/.local/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (80.9.0)
# Requirement already satisfied: sympy==1.13.1 in /home/an0jin/.local/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/an0jin/.local/lib/python3.13/site-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: httpx<1,>=0.28 in /home/an0jin/.local/lib/python3.13/site-packages (from ultralytics-platform>=0.1.45->ultralytics) (0.28.1)
# Requirement already satisfied: anyio in /home/an0jin/.local/lib/python3.13/site-packages (from httpx<1,>=0.28->ultralytics-platform>=0.1.45->ultralytics) (4.15.1)
# Requirement already satisfied: httpcore==1.* in /home/an0jin/.local/lib/python3.13/site-packages (from httpx<1,>=0.28->ultralytics-platform>=0.1.45->ultralytics) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/an0jin/.local/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.28->ultralytics-platform>=0.1.45->ultralytics) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/an0jin/.local/lib/python3.13/site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading ultralytics-8.4.157-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 17.2 MB/s eta 0:00:00
# Using cached cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Using cached nvidia_ml_py-13.610.43-py3-none-any.whl (53 kB)
# Downloading ultralytics_platform-0.1.50-py3-none-any.whl (87 kB)
# Using cached ultralytics_thop-2.1.6-py3-none-any.whl (30 kB)
# Installing collected packages: nvidia-ml-py, cloudpickle, ultralytics-platform, ultralytics-thop, ultralytics
#   Attempting uninstall: ultralytics-thop
#     Found existing installation: ultralytics-thop 2.0.18
#     Uninstalling ultralytics-thop-2.0.18:
#       Successfully uninstalled ultralytics-thop-2.0.18
#   Attempting uninstall: ultralytics
#     Found existing installation: ultralytics 8.4.12
#     Uninstalling ultralytics-8.4.12:
#       Successfully uninstalled ultralytics-8.4.12
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [ultralytics] [ultralytics]
# Successfully installed cloudpickle-3.1.2 nvidia-ml-py-13.610.43 ultralytics-8.4.157 ultralytics-platform-0.1.50 ultralytics-thop-2.1.6
# Note: you may need to restart the kernel to use updated packages.

# %%
from ultralytics import YOLO
import koreanize_matplotlib
# Out:
# WARNING ⚠️ Ultralytics settings updated to the latest schema. Existing values were preserved where possible.
# View Ultralytics Settings with 'yolo settings' or at '/home/an0jin/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/usage/settings.

# %%
# YOLO 사전학습 모델 가중치 로드 (yolo26n.pt)
model = YOLO('yolo26n.pt')

# 얼굴 톤 탐지 모델 학습 실행
model.train(
    data='./dataset/data.yaml', # 데이터셋 경로 및 클래스 정보가 담긴 yaml 파일
    epochs=300,                 # 최대 학습 에폭 수
    imgsz=640,                  # 입력 이미지 해상도 (640x640)
    batch=32,                   # 배치 사이즈
    val=True,                   # 학습 중 검증(Validation) 수행 여부
    # --- 색상 증강 설정: 퍼스널컬러 고유 색조 유지를 위해 보수적으로 설정 ---
    hsv_h=0.0,                  # 색조(Hue) 변화 미적용 (얼굴 톤 왜곡 방지)
    hsv_s=0.0,                  # 채도(Saturation) 변화 미적용
    hsv_v=0.1,                  # 명도(Value/밝기) 미세 조절만 허용
    # --- 기하학 증강 설정 ---
    degrees=0.0,                # 회전 변형 없음
    translate=0.1,              # 위치 이동(Translation) 변형 허용
    scale=0.5,                  # 크기 배율 조절
    fliplr=0.5,                 # 좌우 반전(Horizontal Flip) 50% 확률 적용
    mosaic=0.0,                 # 모자이크 증강 비활성화 (얼굴 색조 혼합 방지)
    flipud=0.0,                 # 상하 반전 비활성화 (얼굴 방향 유지)
    mixup=0.0,                  # MixUp 비활성화
    patience=50,                # 50 에폭 동안 성능 개선 없을 시 조기 종료(Early Stopping)
)
# Out:
# Ultralytics 8.4.157 🚀 Python-3.13.5 torch-2.6.0+cu124 CPU (13th Gen Intel Core i5-1334U)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=False, cfg=None, channels_last=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, cls_remap=True, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=./dataset/data.yaml, degrees=0.0, deterministic=True, device=, dfl=1.5, dgrad=0.5, dis=6.0, distill_model=None, dlam=1.0, dlog=1.0, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=300, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, hsv_h=0.0, hsv_s=0.0, hsv_v=0.1, imgsz=640, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo26n.pt, momentum=0.937, mosaic=0.0, multi_scale=0.0, name=train-2, nbs=64, nms=None, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=50, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, quantize=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/home/an0jin/Documents/GitHub/ToneiverseLinux/DL/face/runs/detect/train-2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/home/an0jin/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 12.0MB/s 0.1s
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5, 3, True]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    119808  ultralytics.nn.modules.block.C3k2            [384, 128, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     34304  ultralytics.nn.modules.block.C3k2            [256, 64, 1, True]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     95232  ultralytics.nn.modules.block.C3k2            [192, 128, 1, True]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    463104  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True, 0.5, True]
#  23        [16, 19, 22]  1    241566  ultralytics.nn.modules.head.Detect           [1, 1, True, [64, 128, 256]]
# YOLO26n summary: 260 layers, 2,504,190 parameters, 2,504,190 gradients, 5.9 GFLOPs
#
# Transferred 606/708 items from pretrained weights
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 80.9±57.2 MB/s, size: 23.2 KB)
# train: Scanning /home/an0jin/Documents/GitHub/ToneiverseLinux/DL/face/dataset/train/labels... 1865 images, 2 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1865/1865 1.1Kit/s 1.7s0.1ss
# train: New cache created: /home/an0jin/Documents/GitHub/ToneiverseLinux/DL/face/dataset/train/labels.cache
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 82.2±37.6 MB/s, size: 9.6 KB)
# val: Scanning /home/an0jin/Documents/GitHub/ToneiverseLinux/DL/face/dataset/valid/labels... 389 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 389/389 1.1Kit/s 0.4s<0.1s
# val: New cache created: /home/an0jin/Documents/GitHub/ToneiverseLinux/DL/face/dataset/valid/labels.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 114 weight(decay=0.0), 126 weight(decay=0.0005), 126 bias(decay=0.0)
# Plotting labels to /home/an0jin/Documents/GitHub/ToneiverseLinux/DL/face/runs/detect/train-2/labels.jpg...
# Using 1865 train, 389 val images for fraction=1.0 at imgsz=640
# Using 0 dataloader workers
# Logging results to /home/an0jin/Documents/GitHub/ToneiverseLinux/DL/face/runs/detect/train-2
# Starting training for 300 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       1/300         0G      1.574      12.13    0.04808         31        640: 10% ━─────────── 6/59 5.2s/it 46.5s<4:368
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 5
#       1 # YOLO 사전학습 모델 가중치 로드 (yolo26n.pt)
#       2 model = YOLO('yolo26n.pt')
#       3
#       4 # 얼굴 톤 탐지 모델 학습 실행
# ----> 5 model.train(
#       6     data='./dataset/data.yaml', # 데이터셋 경로 및 클래스 정보가 담긴 yaml 파일
#       7     epochs=300,                 # 최대 학습 에폭 수
#       8     imgsz=640,                  # 입력 이미지 해상도 (640x640)
#
# File ~/.local/lib/python3.13/site-packages/ultralytics/engine/model.py:880, in Model.train(self, trainer, **kwargs)
#     877     self.model = self.trainer.model
#     878     self.predictor = None  # this module replaced the one the cached predictor wrapped
# --> 880 self.trainer.train()
#     881 # Update model and cfg after training
#     882 if RANK in {-1, 0}:
#
# File ~/.local/lib/python3.13/site-packages/ultralytics/engine/trainer.py:253, in BaseTrainer.train(self)
#     250                 ddp_cleanup(self, str(file))
#     252     else:
# --> 253         self._do_train()
#     254 finally:
#     255     unset_deterministic()  # never leave deterministic state on, including the DDP parent and failed runs
#
# File ~/.local/lib/python3.13/site-packages/ultralytics/engine/trainer.py:531, in BaseTrainer._do_train(self)
#     529     loss, self.loss_items = unwrap_model(self.model).loss(batch, preds)
#     530 else:
# --> 531     loss, self.loss_items = self.model(batch)
#     532 self.loss = loss.sum()
#     533 if RANK != -1:
#
# File ~/.local/lib/python3.13/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.13/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/.local/lib/python3.13/site-packages/ultralytics/nn/tasks.py:160, in BaseModel.forward(self, x, *args, **kwargs)
#     147 """Perform forward pass of the model for either training or inference.
#     148
#     149 If x is a dict, calculates and returns the loss for training. Otherwise, returns predictions for inference.
#    (...)    157     (torch.Tensor): Loss if x is a dict (training), or network predictions (inference).
#     158 """
#     159 if isinstance(x, dict):  # for cases of training and validating while training.
# --> 160     return self.loss(x, *args, **kwargs)
#     161 return self.predict(x, *args, **kwargs)
#
# File ~/.local/lib/python3.13/site-packages/ultralytics/nn/tasks.py:423, in BaseModel.loss(self, batch, preds)
#     421 if preds is None:
#     422     preds = self.forward(batch["img"])
# --> 423 return self.criterion(preds, batch)
#
# File ~/.local/lib/python3.13/site-packages/ultralytics/utils/loss.py:1325, in E2ELoss.__call__(self, preds, batch)
#    1323 preds = self.one2many.parse_output(preds)
#    1324 one2many, one2one = preds["one2many"], preds["one2one"]
# -> 1325 loss_one2many = self.one2many.loss(one2many, batch)
#    1326 loss_one2one = self.one2one.loss(one2one, batch)
#    1327 return loss_one2many[0] * self.o2m + loss_one2one[0] * self.o2o, loss_one2one[1]
#
# File ~/.local/lib/python3.13/site-packages/ultralytics/utils/loss.py:485, in v8DetectionLoss.loss(self, preds, batch)
#     483 """Calculate detection loss using assigned targets."""
#     484 batch_size = preds["boxes"].shape[0]
# --> 485 loss, loss_detach = self.get_assigned_targets_and_loss(preds, batch)[1:]
#     486 return loss * batch_size, loss_detach
#
# File ~/.local/lib/python3.13/site-packages/ultralytics/utils/loss.py:427, in v8DetectionLoss.get_assigned_targets_and_loss(self, preds, batch)
#     424 # Pboxes
#     425 pred_bboxes = self.bbox_decode(anchor_points, pred_distri)  # xyxy, (b, h*w, 4)
# --> 427 _, target_bboxes, target_scores, fg_mask, target_gt_idx = self.assigner(
#     428     pred_scores.detach().sigmoid(),
#     429     (pred_bboxes.detach() * stride_tensor).type(gt_bboxes.dtype),
#     430     anchor_points * stride_tensor,
#     431     gt_labels,
#     432     gt_bboxes,
#     433     mask_gt,
#     434 )
#     436 target_scores_sum = target_scores.sum().clamp_(min=1)  # on the device: no host sync
#     438 # Cls loss with optional class weighting
#
# File ~/.local/lib/python3.13/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.13/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/.local/lib/python3.13/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~/.local/lib/python3.13/site-packages/ultralytics/utils/tal.py:97, in TaskAlignedAssigner.forward(self, pd_scores, pd_bboxes, anc_points, gt_labels, gt_bboxes, mask_gt)
#      88     return (
#      89         torch.full_like(pd_scores[..., 0], self.num_classes),
#      90         torch.zeros_like(pd_bboxes),
#    (...)     93         torch.zeros_like(pd_scores[..., 0]),
#      94     )
#      96 try:
# ---> 97     return self._forward(pd_scores, pd_bboxes, anc_points, gt_labels, gt_bboxes, mask_gt)
#      98 except RuntimeError as e:
#      99     if "out of memory" not in str(e).lower():
#
# File ~/.local/lib/python3.13/site-packages/ultralytics/utils/tal.py:155, in TaskAlignedAssigner._forward(self, pd_scores, pd_bboxes, anc_points, gt_labels, gt_bboxes, mask_gt)
#     137 def _forward(self, pd_scores, pd_bboxes, anc_points, gt_labels, gt_bboxes, mask_gt):
#     138     """Compute the task-aligned assignment.
#     139
#     140     Args:
#    (...)    153         target_gt_idx (torch.Tensor): Target ground truth indices with shape (bs, num_total_anchors).
#     154     """
# --> 155     mask_pos, align_metric, overlaps = self.get_pos_mask(
#     156         pd_scores, pd_bboxes, gt_labels, gt_bboxes, anc_points, mask_gt
#     157     )
#     159     target_gt_idx, fg_mask, mask_pos = self.select_highest_overlaps(
#     160         mask_pos, overlaps, self.n_max_boxes, align_metric
#     161     )
#     163     # Assigned target
#
# File ~/.local/lib/python3.13/site-packages/ultralytics/utils/tal.py:195, in TaskAlignedAssigner.get_pos_mask(self, pd_scores, pd_bboxes, gt_labels, gt_bboxes, anc_points, mask_gt)
#     193 mask_in_gts = self.select_candidates_in_gts(anc_points, gt_bboxes, mask_gt)
#     194 # Get anchor_align metric, (b, max_num_obj, h*w)
# --> 195 align_metric, overlaps = self.get_box_metrics(pd_scores, pd_bboxes, gt_labels, gt_bboxes, mask_in_gts * mask_gt)
#     196 # Get topk_metric mask, (b, max_num_obj, h*w)
#     197 mask_topk = self.select_topk_candidates(align_metric, topk_mask=mask_gt.expand(-1, -1, self.topk).bool())
#
# File ~/.local/lib/python3.13/site-packages/ultralytics/utils/tal.py:222, in TaskAlignedAssigner.get_box_metrics(self, pd_scores, pd_bboxes, gt_labels, gt_bboxes, mask_gt)
#     220 indices = mask_gt.nonzero(as_tuple=True)
#     221 bbox_scores = pd_scores[indices[0], indices[2], gt_labels[indices[0], indices[1], 0].long()]
# --> 222 overlap_values = self.iou_calculation(gt_bboxes[indices[:2]], pd_bboxes[indices[0], indices[2]])
#     223 align_values = bbox_scores.pow(self.alpha) * overlap_values.pow(self.beta)
#     225 overlaps = torch.zeros(shape, dtype=pd_bboxes.dtype, device=pd_bboxes.device)
#
# File ~/.local/lib/python3.13/site-packages/ultralytics/utils/tal.py:241, in TaskAlignedAssigner.iou_calculation(self, gt_bboxes, pd_bboxes)
#     231 def iou_calculation(self, gt_bboxes, pd_bboxes):
#     232     """Calculate IoU for horizontal bounding boxes.
#     233
#     234     Args:
#    (...)    239         (torch.Tensor): IoU values between each pair of boxes.
#     240     """
# --> 241     return bbox_iou(gt_bboxes, pd_bboxes, xywh=False, CIoU=True).squeeze(-1).clamp_(0)
#
# File ~/.local/lib/python3.13/site-packages/ultralytics/utils/metrics.py:148, in bbox_iou(box1, box2, xywh, GIoU, DIoU, CIoU, eps)
#     145     w2, h2 = b2_x2 - b2_x1, b2_y2 - b2_y1 + eps
#     147 # Intersection area
# --> 148 inter = (b1_x2.minimum(b2_x2) - b1_x1.maximum(b2_x1)).clamp_(0) * (
#     149     b1_y2.minimum(b2_y2) - b1_y1.maximum(b2_y1)
#     150 ).clamp_(0)
#     152 # Union Area
#     153 union = w1 * h1 + w2 * h2 - inter + eps
#
# KeyboardInterrupt:

# %%
# 학습 완료 후 리눅스 시스템 자동 전원 종료 (장시간 학습 대비)
# !shutdown now
# Out:
# [sudo] an0jin 암호:
# sudo: 암호가 필요합니다
# ^C
